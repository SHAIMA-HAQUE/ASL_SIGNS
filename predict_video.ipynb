# %%
import cv2
import numpy as np
import keras
from keras import models
from keras import utils
from keras.preprocessing import image
import os
import tensorflow as tf

# %%
model = models.load_model('cnn_10ep_jo_acc97_testac_82_gray.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Capture video
#Extract frames
#Preprocess or resize frames
#predict frames

# %%
print(tf.__version__)
# Out:
# 2.16.1

# %%
print(keras.__version__)
# Out:
# 3.1.1

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import utils
import time
video = cv2.VideoCapture(0)
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
frame_rate = video.get(cv2.CAP_PROP_FPS)
start_time = time.time()
image_size = (180,180)
while True:
    _, frame = video.read()
    frame = cv2.resize(frame, (180, 180))
    # Convert frame to grayscale
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Reshape frame to match model input shape (add channel dimension)
    frame = np.expand_dims(frame, axis=-1)
    input_data = np.expand_dims(frame, axis=0)
    
    # Predict class probabilities
    predictions = model.predict(input_data)
    
    # Get predicted class label
    predicted_class_index = np.argmax(predictions)
    predicted_class = classes[predicted_class_index]
    

    # Customize this part to your liking...
    if predicted_class_index==0: 
        print(f'Predicted class is i_love_you')
    elif predicted_class_index==1:
        print(f'Predicted class is please')
    elif predicted_class_index==2:
        print(f'Predicted class is water')
    elif predicted_class_index==3:
        print(f'Predicted class is welcome')

   # show the word in screen
    # cv2.putText(frame, predicted_class_label, (10, 50), 
    #             cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    classes = ['i_love_you', 'please', 'water', 'welcome']
    predicted_class = classes[predicted_class_index]
    cv2.putText(frame, predicted_class, (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 180, 0), 2)
    cv2.imshow("Prediction", frame)

    key = cv2.waitKey(1)
    if key == ord('q'):
        break
end_time = time.time()

# Calculate total processing time
total_time = end_time - start_time

# Calculate frame rate
calculated_frame_rate = total_frames / total_time

print("Frame rate (from video metadata):", frame_rate)
print("Calculated frame rate:", calculated_frame_rate)

video.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted class is please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class is welcome
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ...
